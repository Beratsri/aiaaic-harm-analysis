# %% [markdown]
# # 04 - Affected Party Classifier
# This notebook trains a multi-label classifier using the manual labels generated in the interim step.

# %%
import pandas as pd
import sys
import os

sys.path.append("../src")
from config import CLEAN_DATA_PATH, MANUAL_LABELS_PATH, AFFECTED_PARTY_MODEL_PATH
from models.affected_party import AffectedPartyClassifier

# %% [markdown]
# ## Load datasets

# %%
df_clean = pd.read_csv(CLEAN_DATA_PATH)
df_labels = pd.read_csv(MANUAL_LABELS_PATH)
print(f"Clean rows: {len(df_clean)}, Labeled rows: {len(df_labels)}")
# Out:
# Clean rows: 2247, Labeled rows: 2247

# %% [markdown]
# ## Train Affected Party Model

# %%
print("Training Affected Party Classifier...")
clf_ap = AffectedPartyClassifier()
clf_ap.fit(df_labels, df_clean)
clf_ap.save(AFFECTED_PARTY_MODEL_PATH)
# Out:
# Training Affected Party Classifier...
#
# ======================================
#   Affected Party Classifier Performance
# ======================================
# Macro F1 Score : 0.5794
# Micro F1 Score : 0.6435
# Weighted F1    : 0.6512
# Samples F1     : 0.6391
# Macro Precision: 0.5363
# Macro Recall   : 0.6415
# --------------------------------------
# Class Name                     | F1-Score   | Precision  | Recall
# --------------------------------------
# Workers                        | 0.7701     | 0.7701     | 0.7701
# RacialEthnicMinorities         | 0.5657     | 0.4870     | 0.6747
# Children                       | 0.5200     | 0.4483     | 0.6190
# Women                          | 0.4219     | 0.3803     | 0.4737
# LGBTQ                          | 0.4000     | 0.4000     | 0.4000
# Disabled                       | 0.4167     | 0.3571     | 0.5000
# Patients                       | 0.5000     | 0.4571     | 0.5517
# Students                       | 0.6164     | 0.6000     | 0.6338
# Citizens                       | 0.7608     | 0.8154     | 0.7130
# Artists                        | 0.7059     | 0.6122     | 0.8333
# Consumers                      | 0.6783     | 0.6290     | 0.7358
# Activists                      | 0.5974     | 0.4792     | 0.7931
# ======================================
#
# Saved Affected Party model to /Users/berat/Desktop/ai ethics project antigravity/models/affected_party_clf.joblib
