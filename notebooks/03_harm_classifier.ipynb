# %% [markdown]
# # 03 - Harm Classifiers (Individual and Societal)
# This notebook trains TF-IDF + Logistic Regression classifiers to predict missing `Harm_Individual` and `Harm_Societal` labels.

# %%
import pandas as pd
import sys
import os

sys.path.append("../src")
from config import CLEAN_DATA_PATH, HARM_INDIVIDUAL_MODEL_PATH, HARM_SOCIETAL_MODEL_PATH
from models.harm_classifier import HarmClassifier

# %% [markdown]
# ## Load cleaned data

# %%
df_clean = pd.read_csv(CLEAN_DATA_PATH)
print(f"Loaded clean data: {df_clean.shape}")
# Out:
# Loaded clean data: (2247, 17)

# %% [markdown]
# ## Train Harm_Individual Model

# %%
print("Training Harm_Individual Classifier...")
clf_ind = HarmClassifier(target_column='Harm_Individual', top_n_classes=15)
clf_ind.fit(df_clean)
clf_ind.save(HARM_INDIVIDUAL_MODEL_PATH)
# Out:
# Training Harm_Individual Classifier...
#
# ======================================
#   Harm_Individual Performance Summary
# ======================================
# Macro F1 Score : 0.5250
# Micro F1 Score : 0.6108
# Weighted F1    : 0.6387
# Samples F1     : 0.6243
# Macro Precision: 0.4534
# Macro Recall   : 0.6591
# --------------------------------------
# Class Name                     | F1-Score   | Precision  | Recall
# --------------------------------------
# Anxiety/distress               | 0.5424     | 0.4706     | 0.6400
# Bodily injury                  | 0.4242     | 0.2917     | 0.7778
# Deception/manipulation         | 0.5000     | 0.4444     | 0.5714
# Discrimination                 | 0.6923     | 0.5455     | 0.9474
# Financial loss                 | 0.5333     | 0.4255     | 0.7143
# Harassment                     | 0.2500     | 0.2000     | 0.3333
# IP/copyright loss              | 0.8824     | 0.9375     | 0.8333
# Job loss/losses                | 0.6364     | 0.5000     | 0.8750
# Loss of life                   | 0.7843     | 0.6897     | 0.9091
# Loss of rights/freedoms        | 0.5455     | 0.4091     | 0.8182
# Opportunity loss               | 0.0000     | 0.0000     | 0.0000
# Other                          | 0.4262     | 0.3514     | 0.5417
# Privacy loss                   | 0.9091     | 0.8511     | 0.9756
# Property damage                | 0.5600     | 0.4118     | 0.8750
# Reputational damage            | 0.5714     | 0.6154     | 0.5333
# Trauma                         | 0.1429     | 0.1111     | 0.2000
# ======================================
#
# Saved Harm_Individual model to /Users/berat/Desktop/ai ethics project antigravity/models/harm_individual_clf.joblib

# %% [markdown]
# ## Train Harm_Societal Model

# %%
print("Training Harm_Societal Classifier...")
clf_soc = HarmClassifier(target_column='Harm_Societal', top_n_classes=15)
clf_soc.fit(df_clean)
clf_soc.save(HARM_SOCIETAL_MODEL_PATH)
# Out:
# Training Harm_Societal Classifier...
#
# ======================================
#   Harm_Societal Performance Summary
# ======================================
# Macro F1 Score : 0.5181
# Micro F1 Score : 0.5837
# Weighted F1    : 0.5997
# Samples F1     : 0.5763
# Macro Precision: 0.4727
# Macro Recall   : 0.5998
# --------------------------------------
# Class Name                     | F1-Score   | Precision  | Recall
# --------------------------------------
# Anxiety/distress               | 0.4889     | 0.4400     | 0.5500
# Discrimination                 | 0.6538     | 0.5667     | 0.7727
# Financial loss                 | 0.5766     | 0.6154     | 0.5424
# Fraud                          | 0.9333     | 0.8750     | 1.0000
# Health deterioration           | 0.4545     | 0.4545     | 0.4545
# IP/copyright loss              | 0.7368     | 0.7000     | 0.7778
# Institutional trust loss       | 0.4091     | 0.3913     | 0.4286
# Job loss/losses                | 0.5263     | 0.4167     | 0.7143
# Loss of life                   | 0.3810     | 0.2667     | 0.6667
# Opportunity loss               | 0.4348     | 0.4167     | 0.4545
# Other                          | 0.6860     | 0.6413     | 0.7375
# Privacy loss                   | 0.9011     | 0.9318     | 0.8723
# Property damage                | 0.0000     | 0.0000     | 0.0000
# Reputational damage            | 0.1702     | 0.1290     | 0.2500
# Stereotyping                   | 0.4615     | 0.3333     | 0.7500
# Trauma                         | 0.4762     | 0.3846     | 0.6250
# ======================================
#
# Saved Harm_Societal model to /Users/berat/Desktop/ai ethics project antigravity/models/harm_societal_clf.joblib
